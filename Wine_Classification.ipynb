# %% [markdown]
# # PROJECT 1
# # QUESTION 3
# # -- Plot the classification data against each of the attributes
#
# #-- Which attribute has the highest correlation with the classification  label?

# %% [markdown]
# # Here we are fetching the wine data

# %%
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

# Common imports
import numpy as np
import os

# %% [markdown]
# # Loading the data

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/minsh30/Project1/master/wine.csv'
Wine = pd.read_csv(url)
Wine.head(5)
# Out:
#    Class  Alcohol  Malic  acid  ...   Hue  OD280/OD315 of diluted wines  Proline
# 0      1    14.23         1.71  ...  1.04                          3.92     1065
# 1      1    13.20         1.78  ...  1.05                          3.40     1050
# 2      1    13.16         2.36  ...  1.03                          3.17     1185
# 3      1    14.37         1.95  ...  0.86                          3.45     1480
# 4      1    13.24         2.59  ...  1.04                          2.93      735
#
# [5 rows x 14 columns]

# %% [markdown]
# # Description like count mean max.... of the dataset

# %%
Wine.describe()
# Out:
#             Class     Alcohol  ...  OD280/OD315 of diluted wines      Proline
# count  178.000000  178.000000  ...                    178.000000   178.000000
# mean     1.938202   13.000618  ...                      2.611685   746.893258
# std      0.775035    0.811827  ...                      0.709990   314.907474
# min      1.000000   11.030000  ...                      1.270000   278.000000
# 25%      1.000000   12.362500  ...                      1.937500   500.500000
# 50%      2.000000   13.050000  ...                      2.780000   673.500000
# 75%      3.000000   13.677500  ...                      3.170000   985.000000
# max      3.000000   14.830000  ...                      4.000000  1680.000000
#
# [8 rows x 14 columns]

# %% [markdown]
# # Information of the dataset explaining which datatype they are

# %%
Wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
# Class                           178 non-null int64
# Alcohol                         178 non-null float64
# Malic  acid                     178 non-null float64
# Ash                             178 non-null float64
# Alcalinity of ash               178 non-null float64
# Magnesium                       178 non-null int64
# Total Phenols                   178 non-null float64
# Flavanoids                      178 non-null float64
# Nonflavanoid phenols            178 non-null float64
# Proanthocyanins                 178 non-null float64
# Color intensity                 178 non-null float64
# Hue                             178 non-null float64
# OD280/OD315 of diluted wines    178 non-null float64
# Proline                         178 non-null int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %% [markdown]
# # Classification of data against each attribute

# %%
# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
Wine.hist(bins=50,figsize=(20,15))
plt.show()

# %% [markdown]
# ## Correlation of attribute with Classification lable "Class"

# %%
corr_matrix=Wine.corr()
corr_matrix["Class"].sort_values(ascending=False)
# Out:
# Class                           1.000000
# Alcalinity of ash               0.517859
# Nonflavanoid phenols            0.489109
# Malic  acid                     0.437776
# Color intensity                 0.265668
# Ash                            -0.049643
# Magnesium                      -0.209179
# Alcohol                        -0.328222
# Proanthocyanins                -0.499130
# Hue                            -0.617369
# Proline                        -0.633717
# Total Phenols                  -0.719163
# OD280/OD315 of diluted wines   -0.788230
# Flavanoids                     -0.847498
# Name: Class, dtype: float64

# %% [markdown]
# # As Alcalinity has the highest correlation with the Classification lable "Class"

# %%
from pandas.plotting import scatter_matrix
attributes = ["Class", "Alcalinity of ash", "OD280/OD315 of diluted wines", "Flavanoids"]
scatter_matrix(Wine[attributes],figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe9e071e7b8>,
# ...
#       dtype=object)
